# %% [markdown]
# # Telecom customer support:

# %% [markdown]
# ### ============== Welcome To Telecom Customer Supporter ==============

# %% [markdown]
# ### import File (numpy, pandas, matplotlib, Seaborn)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Telecom_Customer_Support_Tickets_Gigantic_Dataset - Telecom_Customer_Support_Tickets_Gigantic_Dataset.csv.csv")
df
# Out:
#        Ticket_ID Created_Date   Region       City Issue_Category  Priority  \
# 0         500000   2022-07-27      NaN       Pune        Billing    Medium
# 1         500001   2024-04-04      NaN    Chennai            NaN    Medium
# 2         500002   2024-02-12  Central  Ahmedabad        Network      High
# 3         500003   2022-02-18  Central  Bengaluru        Service       Low
# 4         500004   2023-01-04  Central    Chennai       Hardware  Critical
# ...          ...          ...      ...        ...            ...       ...
# 62495     501126   2023-01-02     West  Hyderabad        Service       Low
# 62496     506196   2024-01-11     West        NaN       Hardware    Medium
# 62497     516269   2022-06-11  Central    Kolkata        Billing       Low
# 62498     542189   2022-05-25    South       Pune            NaN       Low
# 62499     534990   2022-03-05     West     Mumbai        Billing    Medium
#
#        Resolution_Time_Hours Customer_Type  Satisfaction_Score
# ...

# %%
df.head() #
# Out:
#    Ticket_ID Created_Date   Region       City Issue_Category  Priority  \
# 0     500000   2022-07-27      NaN       Pune        Billing    Medium
# 1     500001   2024-04-04      NaN    Chennai            NaN    Medium
# 2     500002   2024-02-12  Central  Ahmedabad        Network      High
# 3     500003   2022-02-18  Central  Bengaluru        Service       Low
# 4     500004   2023-01-04  Central    Chennai       Hardware  Critical
#
#    Resolution_Time_Hours Customer_Type  Satisfaction_Score
# 0                   36.0      Existing                 5.0
# 1                   10.0      Existing                 2.0
# 2                   41.0           New                 2.0
# 3                  206.0           New                 4.0
# 4                   31.0      Existing                 5.0

# %%
df.tail()
# Out:
#        Ticket_ID Created_Date   Region       City Issue_Category Priority  \
# 62495     501126   2023-01-02     West  Hyderabad        Service      Low
# 62496     506196   2024-01-11     West        NaN       Hardware   Medium
# 62497     516269   2022-06-11  Central    Kolkata        Billing      Low
# 62498     542189   2022-05-25    South       Pune            NaN      Low
# 62499     534990   2022-03-05     West     Mumbai        Billing   Medium
#
#        Resolution_Time_Hours Customer_Type  Satisfaction_Score
# 62495                  218.0      Existing                 4.0
# 62496                   10.0           NaN                 NaN
# 62497                   92.0           New                 1.0
# 62498                  100.0           New                 3.0
# 62499                   19.0      Existing                 5.0

# %%
df.shape
# Out:
# (62500, 9)

# %%
df.describe()
# Out:
#            Ticket_ID  Resolution_Time_Hours  Satisfaction_Score
# count   62500.000000           62222.000000        56269.000000
# mean   530003.994160             119.250201            3.220548
# std     17317.636308              68.837770            1.226304
# min    500000.000000               1.000000            1.000000
# 25%    515004.750000              60.000000            2.000000
# 50%    530018.500000             119.000000            3.000000
# 75%    544988.000000             179.000000            4.000000
# max    559999.000000             239.000000            5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62500 entries, 0 to 62499
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ticket_ID              62500 non-null  int64
#  1   Created_Date           62500 non-null  object
#  2   Region                 49957 non-null  object
#  3   City                   55579 non-null  object
#  4   Issue_Category         56190 non-null  object
#  5   Priority               62500 non-null  object
#  6   Resolution_Time_Hours  62222 non-null  float64
#  7   Customer_Type          56374 non-null  object
#  8   Satisfaction_Score     56269 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.3+ MB

# %%
df.dtypes
# Out:
# Ticket_ID                  int64
# Created_Date              object
# Region                    object
# City                      object
# Issue_Category            object
# Priority                  object
# Resolution_Time_Hours    float64
# Customer_Type             object
# Satisfaction_Score       float64
# dtype: object

# %% [markdown]
# #### numerical colunms type = ticket_ID, created_Date, Resolution_Time_Hours, Satisfaction_Score,
# #### categorical colunms type = Region, City, Issue_Category, Priority, Customer_Type.|

# %% [markdown]
# ### now we can create code for numerical colunms

# %% [markdown]
# ### 1️⃣ Ticket_ID
#
# #### conclusion:
# - Total Items: There are 62,500 total entries in this list.
# - Different Types: Out of those, there are 900 unique (different) items.
# - Most Common: The most frequent item is the date 2023-05-01.
# - Frequency: This specific date appears 92 times in the data

# %%
df["Ticket_ID"].info
# Out:
# <bound method Series.info of 0        500000
# 1        500001
# 2        500002
# 3        500003
# 4        500004
#           ...
# 62495    501126
# 62496    506196
# 62497    516269
# 62498    542189
# 62499    534990
# Name: Ticket_ID, Length: 62500, dtype: int64>

# %%
df["Ticket_ID"].describe()
# Out:
# count     62500.000000
# mean     530003.994160
# std       17317.636308
# min      500000.000000
# 25%      515004.750000
# 50%      530018.500000
# 75%      544988.000000
# max      559999.000000
# Name: Ticket_ID, dtype: float64

# %% [markdown]
# ###  2️⃣ Created_Date
#
# #### conclusion:
# - Total Records (count): There are 62,500 total entries in this list.
# - Unique Dates (unique): These entries are spread across 900 different days.
# - Most Common Date (top): The date appearing most often is May 1, 2023 (2023-05-01).
# - Top Date Frequency (freq): On that busiest day (May 1, 2023), there were 92 entries.

# %%
df["Created_Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Created_Date
# Non-Null Count  Dtype
# --------------  -----
# 62500 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["Created_Date"].describe()
# Out:
# count          62500
# unique           900
# top       2023-05-01
# freq              92
# Name: Created_Date, dtype: object

# %%
df["Created_Date"].nunique()
# Out:
# 900

# %% [markdown]
# ### 3️⃣Resolution_Time_Hours
#
# ### conclusion:
# - Total Count: There are 62,222 entries in this dataset.
# - Range: The numbers range from a minimum of 1 to a maximum of 239.
# - The Center: The average (119.25) and the middle value (119) are almost identical, which means the data is perfectly centered.
# - Even Distribution: The data is split into very consistent quarters (25% is at 60, 50% is at 119, and 75% is at 179).

# %%
df["Resolution_Time_Hours"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Resolution_Time_Hours
# Non-Null Count  Dtype
# --------------  -----
# 62222 non-null  float64
# dtypes: float64(1)
# memory usage: 488.4 KB

# %%
df["Resolution_Time_Hours"].describe()
# Out:
# count    62222.000000
# mean       119.250201
# std         68.837770
# min          1.000000
# 25%         60.000000
# 50%        119.000000
# 75%        179.000000
# max        239.000000
# Name: Resolution_Time_Hours, dtype: float64

# %%
df["Resolution_Time_Hours"].nunique()
# Out:
# 239

# %%
# Resolution_Time_Hours Histogram plot:

df["Resolution_Time_Hours"]
plt.hist(df["Resolution_Time_Hours"], bins = 5, edgecolor = "black")
plt.title("Resolution_Time_Hours ")
plt.xlabel("Resolution_Time_Hours")
plt.show()

# %% [markdown]
# ### 4️⃣ Satisfaction_Score
#
# #### conclusion:
# - Participation : There are 56,269 total responses.
# - The Average (mean): The average score is 3.22, which falls slightly above the neutral point (3.00).
# - The Middle (50%/median): Exactly half of the responses are 3 or lower, and half are 3 or higher.
# - Spread of Scores (std): A standard deviation of 1.23 shows that while many people picked the middle, there is a significant spread across all numbers.
# - Typical Range: 50% of your data (the "middle half") falls between 2.0 and 4.0

# %%
df["Satisfaction_Score"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Satisfaction_Score
# Non-Null Count  Dtype
# --------------  -----
# 56269 non-null  float64
# dtypes: float64(1)
# memory usage: 488.4 KB

# %%
df["Satisfaction_Score"].describe()
# Out:
# count    56269.000000
# mean         3.220548
# std          1.226304
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Satisfaction_Score, dtype: float64

# %%
df["Satisfaction_Score"].isnull().sum()
# Out:
# np.int64(6231)

# %%
df["Satisfaction_Score"].fillna(df["Satisfaction_Score"], inplace=True)
df["Satisfaction_Score"].isnull().sum() # check null values fill or not
# Out:
# np.int64(6231)

# %%
df["Satisfaction_Score"].nunique()
# Out:
# 5

# %%
df["Satisfaction_Score"]
plt.figure(figsize=(10,6))
sns.countplot(x=df["Satisfaction_Score"], edgecolor = "black")
plt.title("Satisfaction Score Distribution")
plt.xlabel("Satisfaction Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Now We can Create Code For Categorical Colunms:

# %% [markdown]
# #### 1️⃣ Region
#
# #### conclusion:
# - Participation (count): There are 56,269 total responses.
# - The Average (mean): The average score is 3.22, which falls slightly above the neutral point (3.00).
# - The Middle (50%/median): Exactly half of the responses are 3 or lower, and half are 3 or higher.
# - Spread of Scores (std): A standard deviation of 1.23 shows that while many people picked the middle, there is a significant spread across all numbers.
# - Typical Range: 50% of your data (the "middle half") falls between 2.0 and 4.0

# %%
df["Region"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Region
# Non-Null Count  Dtype
# --------------  -----
# 49957 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["Region"].describe()
# Out:
# count     49957
# unique        5
# top        East
# freq      10144
# Name: Region, dtype: object

# %%
df["Region"].nunique()
# Out:
# 5

# %%
df["Region"].value_counts()
# Out:
# Region
# East       10144
# Central    10002
# North       9990
# South       9971
# West        9850
# Name: count, dtype: int64

# %%
df["Region"].isnull().sum()
# Out:
# np.int64(12543)

# %%
df["Region"].fillna(df["Region"], inplace=True)

df["Region"].isnull().sum()
# Out:
# np.int64(12543)

# %%
df["Region"].value_counts()
plt.figure(figsize=(10,6))
sns.histplot(df["Region"], edgecolor='black', bins=10)
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
#  create boxplot to check outliers :
df["Region"].value_counts()
plt.figure(figsize=(10,6))
sns.boxplot(y=df["Region"])  
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ###  2️⃣ City
#
# #### conclusion:
# - Total Entries (count): There are 55,579 total records in this column.
# - Categories (unique): The data is divided into only 8 different categories (likely cities).
# - Most Common (top): Bengaluru is the most frequent category.
# - Frequency (freq): Bengaluru appears 7,129 times out of the total.

# %%
df["City"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: City
# Non-Null Count  Dtype
# --------------  -----
# 55579 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["City"].describe()
# Out:
# count         55579
# unique            8
# top       Bengaluru
# freq           7129
# Name: City, dtype: object

# %%
df["City"].nunique()
# Out:
# 8

# %%
df["City"].value_counts()
# Out:
# City
# Bengaluru    7129
# Chennai      7115
# Pune         7000
# Delhi        6995
# Hyderabad    6970
# Ahmedabad    6887
# Kolkata      6752
# Mumbai       6731
# Name: count, dtype: int64

# %%
df["City"].isnull().sum()
# Out:
# np.int64(6921)

# %%
df["City"].fillna(df["City"], inplace=True)

# %%
df["City"]
plt.figure(figsize=(10,6))
sns.countplot(x=df["City"], edgecolor = "black", color="orange")
plt.title("City Distribution")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %%
#  create boxplot to check outliers :
df["City"].value_counts()
plt.figure(figsize=(10,6))
sns.boxplot(y=df["City"])  
plt.title("City Distribution")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 3️⃣ Issue_Category
#
# #### conclusion:
# - Total Entries (count): There are 56,190 records.
# - Categories (unique): There are only 5 different categories in the entire dataset.
# - Most Common (top): "Billing" is the most frequent category.
# - Frequency (freq): "Billing" appears 11,344 times.

# %%
df["Issue_Category"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Issue_Category
# Non-Null Count  Dtype
# --------------  -----
# 56190 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["Issue_Category"].describe()
# Out:
# count       56190
# unique          5
# top       Billing
# freq        11344
# Name: Issue_Category, dtype: object

# %%
df["Issue_Category"].value_counts()
# Out:
# Issue_Category
# Billing     11344
# Network     11311
# Software    11278
# Service     11178
# Hardware    11079
# Name: count, dtype: int64

# %%
df["Issue_Category"].isnull
# Out:
# <bound method Series.isnull of 0         Billing
# 1             NaN
# 2         Network
# 3         Service
# 4        Hardware
#            ...
# 62495     Service
# 62496    Hardware
# 62497     Billing
# 62498         NaN
# 62499     Billing
# Name: Issue_Category, Length: 62500, dtype: object>

# %%
df["Issue_Category"].nunique()
# Out:
# 5

# %%
df["Issue_Category"].value_counts()
sns.barplot(x=df["Issue_Category"].index, y=df["Issue_Category"].values)
plt.title("Issue Category Distribution")
plt.xlabel("Issue Category")

plt.show()

# %% [markdown]
# ### 4️⃣ Priority
#
# #### conclusion:
# - Total Records: There are 62,500 entries.
# - Groups: There are only 4 levels (likely Low, Medium, High, and Urgent).
# - Most Common: "Low" is the most frequent status.
# - Top Frequency: "Low" appears 22,022 times.

# %%
df["Priority"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Priority
# Non-Null Count  Dtype
# --------------  -----
# 62500 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["Priority"].describe()
# Out:
# count     62500
# unique        4
# top         Low
# freq      22002
# Name: Priority, dtype: object

# %%
df["Priority"].value_counts()
# Out:
# Priority
# Low         22002
# Medium      21725
# High        12499
# Critical     6274
# Name: count, dtype: int64

# %%
df["Priority"].nunique()
# Out:
# 4

# %%
df["Priority"].value_counts()
plt.figure(figsize=(10,6))
sns.countplot(x=df["Priority"], edgecolor = "black", color="purple")
plt.title("Priority Distribution")
plt.xlabel("Priority")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 5️⃣ Customer_Type
#
# #### conclusion:
# - Total Records (count): There are 56,374 total entries.
# - Categories (unique): There are exactly 2 options (likely "Existing" and "New" customers/accounts).
# - Most Common (top): The most frequent category is "Existing".
# - Top Frequency (freq): "Existing" appears 31,357 times.

# %%
df["Customer_Type"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 62500 entries, 0 to 62499
# Series name: Customer_Type
# Non-Null Count  Dtype
# --------------  -----
# 56374 non-null  object
# dtypes: object(1)
# memory usage: 488.4+ KB

# %%
df["Customer_Type"].describe()
# Out:
# count        56374
# unique           2
# top       Existing
# freq         31357
# Name: Customer_Type, dtype: object

# %%
df["Customer_Type"].value_counts()
# Out:
# Customer_Type
# Existing    31357
# New         25017
# Name: count, dtype: int64

# %%
df["Customer_Type"].nunique()
# Out:
# 2

# %%
df["Customer_Type"]
plt.figure(figsize=(10,6))
sns.countplot(x=df["Customer_Type"], edgecolor = "black", color="Red")
plt.title("Customer Distribution")
plt.xlabel("Customer")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Issue category Wise Ticket Count:

# %%
df[["Issue_Category", "Ticket_ID"]].value_counts()
# Out:
# Issue_Category  Ticket_ID
# Hardware        504503       2
# Billing         516758       2
# Hardware        537447       2
# Billing         549732       2
#                 537058       2
#                             ..
# Software        559977       1
#                 559982       1
#                 559990       1
#                 559991       1
#                 559915       1
# Name: count, Length: 53960, dtype: int64

# %%
df[["Issue_Category", "Ticket_ID"]].value_counts()
# Out:
# Issue_Category  Ticket_ID
# Hardware        504503       2
# Billing         516758       2
# Hardware        537447       2
# Billing         549732       2
#                 537058       2
#                             ..
# Software        559977       1
#                 559982       1
#                 559990       1
#                 559991       1
#                 559915       1
# Name: count, Length: 53960, dtype: int64

# %% [markdown]
# ### Customer VS Satisfication Analysis:

# %%
df[["Customer_Type", "Satisfaction_Score"]]
# Out:
#       Customer_Type  Satisfaction_Score
# 0          Existing                 5.0
# 1          Existing                 2.0
# 2               New                 2.0
# 3               New                 4.0
# 4          Existing                 5.0
# ...             ...                 ...
# 62495      Existing                 4.0
# 62496           NaN                 NaN
# 62497           New                 1.0
# 62498           New                 3.0
# 62499      Existing                 5.0
#
# [62500 rows x 2 columns]

# %%
df[["Customer_Type", "Satisfaction_Score"]].value_counts()
# Out:
# Customer_Type  Satisfaction_Score
# Existing       4.0                   7821
#                3.0                   7753
# New            4.0                   6273
#                3.0                   6238
# Existing       2.0                   4813
#                5.0                   4677
# New            2.0                   3850
#                5.0                   3688
# Existing       1.0                   3187
# New            1.0                   2441
# Name: count, dtype: int64

# %%
df[["Customer_Type", "Satisfaction_Score"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62500 entries, 0 to 62499
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_Type       56374 non-null  object
#  1   Satisfaction_Score  56269 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 976.7+ KB

# %%
df[["Customer_Type", "Satisfaction_Score"]].nunique()
# Out:
# Customer_Type         2
# Satisfaction_Score    5
# dtype: int64
